# %% [markdown]
# <a href="https://colab.research.google.com/github/maksimovicd501-wq/desktop-tutorial/blob/main/Primer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
gfbufeufbrfberf
# Out:
# fatal: destination path 'desktop-tutorial' already exists and is not an empty directory.
# /content/desktop-tutorial
